# %%
print("hello")
# Out:
# hello

# %%
import os
import openai
from dotenv import load_dotenv

# %%
pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (1.78.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from openai) (2.6.3)
# Requirement already satisfied: sniffio in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 1.78.0
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: c:\users\dell\appdata\local\programs\python\python310\lib\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# OPENAI_API_KEY

# %%
openai.api_key = OPENAI_API_KEY

# %%
import pandas as pd
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5364\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.DataFrame(openai.Model.list()['data'])
# Out:
#                                        id object     created         owned_by
# 0                                dall-e-3  model  1698785189           system
# 1                                dall-e-2  model  1698798177           system
# 2         gpt-4o-audio-preview-2024-10-01  model  1727389042           system
# 3                  text-embedding-3-small  model  1705948997           system
# 4                             babbage-002  model  1692634615           system
# 5                      o1-mini-2024-09-12  model  1725648979           system
# 6                                 o1-mini  model  1725649008           system
# 7                  text-embedding-ada-002  model  1671217299  openai-internal
# 8                  text-embedding-3-large  model  1705953180           system
# 9               gpt-4o-mini-audio-preview  model  1734387424           system
# 10                   gpt-4o-audio-preview  model  1727460443           system
# 11                  o1-preview-2024-09-12  model  1725648865           system
# 12            gpt-3.5-turbo-instruct-0914  model  1694122472           system
# 13             gpt-4o-mini-search-preview  model  1741391161           system
# 14                      gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 15                            davinci-002  model  1692634301           system
# 16                     gpt-3.5-turbo-1106  model  1698959748           system
# 17                  gpt-4o-search-preview  model  1741388720           system
# 18                 gpt-3.5-turbo-instruct  model  1692901427           system
# 19                          gpt-3.5-turbo  model  1677610602           openai
# 20  gpt-4o-mini-search-preview-2025-03-11  model  1741390858           system
# 21                      gpt-4o-2024-11-20  model  1739331543           system
# 22                              whisper-1  model  1677532384  openai-internal
# 23                      gpt-4o-2024-05-13  model  1715368132           system
# 24                             o1-preview  model  1725648897           system
# 25                        gpt-4o-mini-tts  model  1742403959           system
# 26                      gpt-4o-transcribe  model  1742068463           system
# 27                        gpt-4.5-preview  model  1740623059           system
# 28             gpt-4.5-preview-2025-02-27  model  1740623304           system
# 29       gpt-4o-search-preview-2025-03-11  model  1741388170           system
# 30             omni-moderation-2024-09-26  model  1732734466           system
# 31                            gpt-image-1  model  1745517030           system
# 32                               tts-1-hd  model  1699046015           system
# 33                                 gpt-4o  model  1715367049           system
# 34                          tts-1-hd-1106  model  1699053533           system
# 35                      gpt-4o-2024-08-06  model  1722814719           system
# 36                 gpt-4o-mini-2024-07-18  model  1721172717           system
# 37                           gpt-4.1-mini  model  1744318173           system
# 38                            gpt-4o-mini  model  1721172741           system
# 39   gpt-4o-mini-audio-preview-2024-12-17  model  1734115920           system
# 40                     gpt-3.5-turbo-0125  model  1706048358           system
# 41                                  tts-1  model  1681940951  openai-internal
# 42                             tts-1-1106  model  1699053241           system
# 43                 gpt-4o-mini-transcribe  model  1742068596           system
# 44                gpt-4.1-mini-2025-04-14  model  1744317547           system
# 45                                gpt-4.1  model  1744316542           system
# 46                     gpt-4.1-2025-04-14  model  1744315746           system
# 47                gpt-4.1-nano-2025-04-14  model  1744321025           system
# 48                 omni-moderation-latest  model  1731689265           system
# 49                           gpt-4.1-nano  model  1744321707           system

# %% [markdown]
# # ChatCompletion API and Completion API
#
# - Completion API: Hooks you up with text completions from a single prompt.
#
# - Chat Completion API: Nails it in the chat game, keeping the conversational flow intact

# %% [markdown]
# # ChatCompletion API

# %%
try:
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": "Hello, How are you?"}
        ]
    )
    print(response["choices"][0]["message"]["content"])
except openai.error.OpenAIError as e:
    print(f"Error: {e}")

# %%
prompt = "Hello, How are you?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ]
)

print(response["choices"][0]['message']['content'])
# Out:
# Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %%
# ChatCompletion API 

prompt1 = "Hello How are you?"
prompt2 = "I am 25 years old & I am a Programmer"
prompt3 = "Tell me about me"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt1},
        {"role": "user", "content": prompt2},
        {"role": "user", "content": prompt3},
    ]
)

print(response["choices"][0]["message"]["content"])
# Out:
# Based on the information you provided, you are a 25-year-old programmer. Is there anything specific you would like to know or discuss?

# %%
prompt = "What is Python?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    max_tokens = 25
)

print(response["choices"][0]['message']['content'])
# Out:
# Python is a popular high-level programming language known for its simplicity and readability. It is widely used in various fields such as web

# %%
prompt = "What is Python?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    max_tokens = 25
)

print(response)
# Out:
# {
#   "id": "chatcmpl-A5RCX6zaPmRR8rsuQxtplKFDtB7cp",
#   "object": "chat.completion",
#   "created": 1725859565,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Python is a high-level, interpreted programming language known for its simplicity and readability. It supports multiple paradigms such as procedural",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 25,
#     "total_tokens": 46
#   },
#   "system_fingerprint": null
# }

# %%
# ChatCompletion API 

prompt = "What is Python?"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6
)

print(response["choices"][0]["message"]["content"])
# Out:
# Python is a high-level, interpreted programming language known for its simplicity and readability. It is widely used for web development, data analysis, artificial intelligence, scientific computing, and more. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming.

# %%
# ChatCompletion API 

prompt = "What is Python?"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
    n = 3
)

print(response)
# Out:
# {
#   "id": "chatcmpl-A5RLwUQKBGWbNMWqKGaw8MSSeQ0R6",
#   "object": "chat.completion",
#   "created": 1725860148,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Python is a high-level, versatile programming language known for its simplicity and readability. It is widely used in various fields such as web development, data science, artificial intelligence, and automation. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Its extensive standard library and active community make it a popular choice for both beginners and experienced programmers.",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     },
#     {
#       "index": 1,
#       "message": {
#         "role": "assistant",
#         "content": "Python is a high-level programming language known for its simplicity and readability. It is widely used for web development, data analysis, artificial intelligence, scientific computing, and more. Python emphasizes code readability and has a large standard library that supports a wide range of functionalities.",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     },
#     {
#       "index": 2,
#       "message": {
#         "role": "assistant",
#         "content": "Python is a high-level, interpreted programming language known for its simplicity and readability. It is widely used in various applications such as web development, data analysis, artificial intelligence, scientific computing, and more. Python emphasizes code readability and has a large standard library that supports various programming tasks.",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 182,
#     "total_tokens": 203
#   },
#   "system_fingerprint": null
# }

# %%
# ChatCompletion API 

prompt = "Give me the sentiment of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
# Out:
# The sentiment of the sentence "This Movie is Amazing!" is positive.

# %%
# ChatCompletion API 

prompt = "Give me hindi transilation of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
# Out:
# यह फिल्म बहुत शानदार है!

# %%
# ChatCompletion API 

prompt = "Detect the language of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
# Out:
# The sentence "This Movie is Amazing!" is in English.

# %%
# ChatCompletion API 

prompt = "Give me a Python code to add 2 numbers"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
# Out:
# Sure! Here is a simple Python code to add two numbers:
#
# ```python
# num1 = 5
# num2 = 3
#
# sum = num1 + num2
#
# print("The sum of", num1, "and", num2, "is:", sum)
# ```
#
# You can change the values of `num1` and `num2` to add any two numbers you want.

# %% [markdown]
# # Completion API

# %%
prompt = "What is Python"
response = openai.Completion.create(
    model = "babbage-002",
    prompt = prompt
)
print(response)
# Out:
# {
#   "id": "cmpl-A5RR3gXZTXSRiqfkFZsaqjSK6s3FA",
#   "object": "text_completion",
#   "created": 1725860465,
#   "model": "babbage-002",
#   "choices": [
#     {
#       "text": "?\n\nThanks for the updates Addison. Personally I vote for doing it on the Survey",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 3,
#     "completion_tokens": 16,
#     "total_tokens": 19
#   }
# }
